# %% [markdown]
# # Pertemuan 5

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
data.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# 25%         0.000000      93.000000    1417.237975    1416.994900
# 50%         0.000000     103.000000    1500.945550    1500.954400
# 75%         0.000000     112.000000    1576.060000    1576.291625
# max         1.000000     186.000000    1853.104500    1853.104500
#
#            win_equiv        opp_pts      opp_elo_i      opp_elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean       41.707889     102.729982    1495.236055    1495.236055
# std        10.627332      14.814845     112.139945     112.461687
# min        10.152501       0.000000    1091.644500    1085.774400
# 25%        34.103035      93.000000    1417.237975    1416.994900
# 50%        42.113357     103.000000    1500.945550    1500.954400
# 75%        49.635328     112.000000    1576.060000    1576.291625
# max        71.112038     186.000000    1853.104500    1853.104500
#
#             forecast
# count  126314.000000
# mean        0.500000
# std         0.215252
# min         0.020447
# 25%         0.327989
# 50%         0.500000
# 75%         0.672011
# max         0.979553

# %%
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)

# %%
data["team_id"]
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
data["team_id"].nunique()
# Out:
# 104

# %%
data["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
data["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# Steamrollers     168
# Packers           72
# Redskins          65
# Rebels            63
# Waterloo          62
# Denver            62
# Falcons           60
# Jets              60
# Ironmen           60
# Huskies           60
# Name: fran_id, dtype: int64

# %%
data.loc[data["team_id"] == "LAL", "date_game"].max()
# Out:
# '6/9/2009'

# %%
data.loc[data["team_id"] == "LAL", "date_game"].min()
# Out:
# '1/1/1961'

# %% [markdown]
# ## Pandas data series
# pada masing-masing kolom, pandas menyimpan 1 series (mirip seperti numpy array)
# Basicnya itu array numpy, namun kalo ini indexnya ngga cuma bisa pake angka aja

# %%
revenues = pd.Series([100,323,700])

# %%
revenues.values
# Out:
# array([100, 323, 700], dtype=int64)

# %%
revenues[1]
# Out:
# 323

# %%
city_revenues = pd.Series(
    [100,323,700],
     index = ["Amsterdam", "Toronto", "Tokyo"]
)

# %%
city_employee_count = pd.Series(
    {
        "Amsterdam" : 5,
        "Tokyo" : 9
    }
)

# %%
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        9
# dtype: int64

# %%
"Toronto" in city_employee_count.index
# Out:
# False

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count": city_employee_count
})

# %%
city_data.values
# Out:
# array([[100.,   5.],
#        [700.,   9.],
#        [323.,  nan]])

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
# menampilkan kedua macam indekx, kolom dan baris
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[0]
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.columns
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
"Tokyo" in city_data
# Out:
# False

# %%
"Amsterdam" in city_data
# Out:
# False

# %%
"revenue" in city_data
# Out:
# True

# %%
data
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# 1                1            0     NYK     Knicks   68  1300.00  1306.72
# 2                1            0     CHS      Stags   63  1300.00  1309.65
# 3                2            0     NYK     Knicks   47  1306.72  1297.07
# 4                1            0     DTF    Falcons   33  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 0                  H           L      0.64   NaN
# 1                  A           W      0.36   NaN
# 2                  H           W      0.63   NaN
# 3                  A           L      0.37   NaN
# 4                  H           L      0.64   NaN
# ...              ...         ...       ...   ...
# 126309             H           L      0.55   NaN
# 126310             H           W      0.77   NaN
# 126311             A           L      0.23   NaN
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN
#
# [126314 rows x 23 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
"points" in data.columns
# Out:
# False

# %%
"pts" in data.columns
# Out:
# True

# %% [markdown]
# ## Slicing

# %%
city_revenues
# Out:
# Amsterdam    100
# Toronto      323
# Tokyo        700
# dtype: int64

# %%
city_revenues[1:2]
# Out:
# Toronto    323
# dtype: int64

# %%
city_revenues["Amsterdam":"Toronto"]
# Out:
# Amsterdam    100
# Toronto      323
# dtype: int64

# %%
colors = pd.Series(
    ["red", "purple" , "blue", "green", "pink"],
    index = [1,2,3,5,10]
)

# %%
colors
# Out:
# 1        red
# 2     purple
# 3       blue
# 5      green
# 10      pink
# dtype: object

# %%
colors[1]
# Out:
# 'red'

# %%
colors[5]
# Out:
# 'green'

# %%
# Mengakses berdasarkan lokasinya/posisinya
colors.loc[3]
# Out:
# 'blue'

# %%
# 1 sampe 3
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.iloc[-1]
# Out:
# 'pink'

# %%
data.loc[0]
# Out:
# gameorder                   1
# game_id          194611010TRH
# lg_id                     NBA
# _iscopy                     0
# year_id                  1947
# date_game           11/1/1946
# seasongame                  1
# is_playoffs                 0
# team_id                   TRH
# fran_id               Huskies
# pts                        66
# elo_i                  1300.0
# elo_n                 1293.28
# win_equiv               40.29
# opp_id                    NYK
# opp_fran               Knicks
# opp_pts                    68
# opp_elo_i              1300.0
# opp_elo_n             1306.72
# game_location               H
# game_result                 L
# forecast                 0.64
# notes                     NaN
# Name: 0, dtype: object

# %%
data.loc[0, "game_id"]
# Out:
# '194611010TRH'

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t monokai

# %%
city_data["revenue"]
# Out:
# Amsterdam    100
# Tokyo        700
# Toronto      323
# Name: revenue, dtype: int64

# %%
toys = pd.DataFrame(
    {
        "name": ["ball", "Rubik's cube"],
        "shape" : ["sphere", "cube"]
    }
)

# %%
toys["shape"]
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %%
city_data.loc["Amsterdam":"Toronto"]
# Out:
#            revenue  employee_count
# Amsterdam      100             5.0
# Tokyo          700             9.0
# Toronto        323             NaN

# %%
city_data.iloc[1]
# Out:
# revenue           700.0
# employee_count      9.0
# Name: Tokyo, dtype: float64

# %%
city_data.loc["Amsterdam", "revenue"]
# Out:
# 100

# %%
city_data.loc[["Amsterdam", "Toronto"], ["revenue", "employee_count"]]
# Out:
#            revenue  employee_count
# Amsterdam      100             5.0
# Toronto        323             NaN

# %%
ers['fran_id'].value_counts{}
# Out:
#   File "C:\Users\ACER\AppData\Local\Temp\ipykernel_5404\1271506954.py", line 1
#     ers['fran_id'].value_counts{}
#                                ^
# SyntaxError: invalid syntax

# %%
data[
#     memfilter data sesuai kebutuhan aja
    (data["_iscopy"] == 0) &
    (data["pts"]) > 100 &
    (data["opp_pts"] > 100) &
#     (data["team_id"] == "LAL") 
    (data["notes"].notna())
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# 14              8  194611050BOS   NBA        0     1947  11/5/1946
# ...           ...           ...   ...      ...      ...        ...
# 126283      63142  201505170HOU   NBA        0     2015  5/17/2015
# 126286      63144  201505200ATL   NBA        0     2015  5/20/2015
# 126288      63145  201505210GSW   NBA        0     2015  5/21/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 2                1            0     CHS         Stags   63  1300.00  1309.65
# 4                1            0     DTF       Falcons   33  1300.00  1279.62
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# 11               1            0     CLR        Rebels   71  1300.00  1307.12
# 14               2            0     BOS       Celtics   55  1294.85  1288.41
# ...            ...          ...     ...           ...  ...      ...      ...
# 126283          94            1     HOU       Rockets  113  1659.66  1669.54
# 126286          95            1     ATL         Hawks   89  1613.94  1603.66
# 126288          94            1     GSW      Warriors   99  1789.74  1791.23
# 126305          99            1     GSW      Warriors   93  1806.20  1797.50
# 126312         102            1     CLE     Cavaliers   97  1700.74  1692.09
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# 7           41.54    BOS    Celtics       53    1300.00    1294.85
# 11          41.75    TRH    Huskies       60    1293.28    1286.15
# 14          39.79    CHS      Stags       57    1309.65    1316.08
# ...           ...    ...        ...      ...        ...        ...
# 126283      57.35    LAC   Clippers      100    1704.43    1694.54
# 126286      51.18    CLE  Cavaliers       97    1678.98    1689.25
# 126288      66.63    HOU    Rockets       98    1667.15    1665.66
# 126305      67.03    CLE  Cavaliers       95    1708.17    1716.87
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
#
#        game_location game_result  forecast notes
# 2                  H           W      0.63   NaN
# 4                  H           L      0.64   NaN
# 7                  H           W      0.64   NaN
# 11                 H           W      0.65   NaN
# 14                 H           L      0.62   NaN
# ...              ...         ...       ...   ...
# 126283             H           W      0.58   NaN
# 126286             H           L      0.55   NaN
# 126288             H           W      0.78   NaN
# 126305             H           L      0.76   NaN
# 126312             H           L      0.48   NaN
#
# [31651 rows x 23 columns]

# %% [markdown]
# # Grouping

# %%
city_revenues.sum()
# Out:
# 1123

# %%
city_revenues.max()
# Out:
# 700

# %%
city_revenues.mean()
# Out:
# 374.3333333333333

# %%
city_revenues.std()
# Out:
# 303.27600190805293

# %%
data
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# 1                1            0     NYK     Knicks   68  1300.00  1306.72
# 2                1            0     CHS      Stags   63  1300.00  1309.65
# 3                2            0     NYK     Knicks   47  1306.72  1297.07
# 4                1            0     DTF    Falcons   33  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 0                  H           L      0.64   NaN
# 1                  A           W      0.36   NaN
# 2                  H           W      0.63   NaN
# 3                  A           L      0.37   NaN
# 4                  H           L      0.64   NaN
# ...              ...         ...       ...   ...
# 126309             H           L      0.55   NaN
# 126310             H           W      0.77   NaN
# 126311             A           L      0.23   NaN
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN
#
# [126314 rows x 23 columns]

# %%
data.groupby(by="fran_id")["pts"].sum()
# Out:
# fran_id
# Baltimore        37219
# Bombers          17793
# Bucks           418326
# Bulls           437269
# Capitols         22387
# Cavaliers       380416
# Celtics         626484
# Clippers        380523
# Colonels         94435
# Condors          49642
# Denver            4818
# Falcons           3797
# Floridians       49568
# Grizzlies       157683
# Hawks           567261
# Heat            229103
# Hornets          84489
# Huskies           3995
# Ironmen           3674
# Jazz            363155
# Jets              4482
# Kings           569245
# Knicks          582497
# Lakers          637444
# Magic           219436
# Mavericks       309239
# Nets            417809
# Nuggets         445780
# Olympians        22864
# Pacers          438288
# Packers           6193
# Pelicans        220794
# Pistons         572758
# Raptors         158370
# Rebels            4474
# Redskins          5372
# Rockets         432504
# Sails            30080
# Sixers          585891
# Sounds           75582
# Spirits          85874
# Spurs           453822
# Squires          91127
# Stags            20398
# Stars            84940
# Steamrollers     12372
# Suns            437486
# Thunder         437735
# Timberwolves    207693
# Trailblazers    402695
# Warriors        591224
# Waterloo          4921
# Wizards         474809
# Name: pts, dtype: int64

# %%
data[data['year_id'] > 2010].groupby(by="fran_id")["pts"].sum()
# Out:
# fran_id
# Bucks           38901
# Bulls           42723
# Cavaliers       40371
# Celtics         41512
# Clippers        44908
# Grizzlies       43130
# Hawks           43167
# Heat            47815
# Hornets         37081
# Jazz            38705
# Kings           39439
# Knicks          40847
# Lakers          42040
# Magic           38780
# Mavericks       43754
# Nets            40347
# Nuggets         43048
# Pacers          43155
# Pelicans        38677
# Pistons         38089
# Raptors         39971
# Rockets         44309
# Sixers          39183
# Spurs           48162
# Suns            39934
# Thunder         48093
# Timberwolves    39387
# Trailblazers    41633
# Warriors        44937
# Wizards         40140
# Name: pts, dtype: int64

# %%
data[
    (data["fran_id"] == "Celtics") &
    (data["year_id"] > 2010)
].groupby(by=["year_id", "team_id", "game_result"])["game_id"].count()
# Out:
# year_id  team_id  game_result
# 2011     BOS      L              30
#                   W              61
# 2012     BOS      L              36
#                   W              50
# 2013     BOS      L              44
#                   W              43
# 2014     BOS      L              57
#                   W              25
# 2015     BOS      L              46
#                   W              40
# Name: game_id, dtype: int64

# %%
data[
    (data["fran_id"] == "Warriors") &
    (data["year_id"] == 2015)
].groupby(by=["year_id", "is_playoffs"])["pts"].mean()
# Out:
# year_id  is_playoffs
# 2015     0              109.95
#          1              103.29
# Name: pts, dtype: float64

# %%
nba = data.copy()

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# 1                1            0     NYK     Knicks   68  1300.00  1306.72
# 2                1            0     CHS      Stags   63  1300.00  1309.65
# 3                2            0     NYK     Knicks   47  1306.72  1297.07
# 4                1            0     DTF    Falcons   33  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 0                  H           L      0.64   NaN
# 1                  A           W      0.36   NaN
# 2                  H           W      0.63   NaN
# 3                  A           L      0.37   NaN
# 4                  H           L      0.64   NaN
# ...              ...         ...       ...   ...
# 126309             H           L      0.55   NaN
# 126310             H           W      0.77   NaN
# 126311             A           L      0.23   NaN
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN
#
# [126314 rows x 23 columns]

# %%
nba["pts_diff"] = nba["pts"] - nba["opp_pts"]

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# 1                1            0     NYK     Knicks   68  1300.00  1306.72
# 2                1            0     CHS      Stags   63  1300.00  1309.65
# 3                2            0     NYK     Knicks   47  1306.72  1297.07
# 4                1            0     DTF    Falcons   33  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes  pts_diff
# 0                  H           L      0.64   NaN        -2
# 1                  A           W      0.36   NaN         2
# 2                  H           W      0.63   NaN        16
# 3                  A           L      0.37   NaN       -16
# 4                  H           L      0.64   NaN       -17
# ...              ...         ...       ...   ...       ...
# 126309             H           L      0.55   NaN       -21
# 126310             H           W      0.77   NaN        13
# 126311             A           L      0.23   NaN       -13
# 126312             H           L      0.48   NaN        -8
# 126313             A           W      0.52   NaN         8
#
# [126314 rows x 24 columns]

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba["pts_diff"].max()
# Out:
# 68

# %%
nba["pts_diff_abs"] = np.abs(nba["pts_diff"])

# %%
# nba["pts_diff_abs"] = np.abs(nba["pts_diff"])
# Out:
# (126314, 25)

# %%
# Manipulasi kolom
#     merubah nama kolom
nba_rename = nba.rename(
columns= {
    "game_result" : "result", "game_location":"location"
    replace == true
})

# %%
nba_rename
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# 1                1            0     NYK     Knicks   68  1300.00  1306.72
# 2                1            0     CHS      Stags   63  1300.00  1309.65
# 3                2            0     NYK     Knicks   47  1306.72  1297.07
# 4                1            0     DTF    Falcons   33  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n location  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72        H
# 1           41.71    TRH    Huskies       66    1300.00    1293.28        A
# 2           42.01    NYK     Knicks       47    1306.72    1297.07        H
# 3           40.69    CHS      Stags       63    1300.00    1309.65        A
# 4           38.86    WSC   Capitols       50    1300.00    1320.38        H
# ...           ...    ...        ...      ...        ...        ...      ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98        H
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74        H
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63        A
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29        H
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09        A
#
#        result  forecast notes  pts_diff  pts_diff_abs
# 0           L      0.64   NaN        -2             2
# 1           W      0.36   NaN         2             2
# 2           W      0.63   NaN        16            16
# 3           L      0.37   NaN       -16            16
# 4           L      0.64   NaN       -17            17
# ...       ...       ...   ...       ...           ...
# 126309      L      0.55   NaN       -21            21
# 126310      W      0.77   NaN        13            13
# 126311      L      0.23   NaN       -13            13
# 126312      L      0.48   NaN        -8             8
# 126313      W      0.52   NaN         8             8
#
# [126314 rows x 25 columns]

# %%
elo_col = ["elo_i", "opp_elo_i", "opp_elo_n"]

# %%
# menghapus
nba.drop(elo_col, axes=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5404\2775947571.py in <module>
#       1 # menghapus
# ----> 2 nba.drop(elo_col, axes=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: drop() got an unexpected keyword argument 'axes'

# %%
# nba['location'] = pd.Categorical(nba['location'])

# %%
# nba['location'].dtype

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
#  17  opp_elo_i      126314 non-null  float64
#  18  opp_elo_n      126314 non-null  float64
#  19  game_location  126314 non-null  object
#  20  game_result    126314 non-null  object
#  21  forecast       126314 non-null  float64
#  22  notes          5424 non-null    object
#  23  pts_diff       126314 non-null  int64
#  24  pts_diff_abs   126314 non-null  int64
# dtypes: float64(6), int64(9), object(10)
# memory usage: 24.1+ MB

# %%
nba.dropna(axis=0)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 930             28            0     WSC      Capitols   71  1469.35  1454.90
# 931             31            0     BLB     Baltimore   95  1434.05  1448.50
# 1084            49            1     WSC      Capitols   70  1465.90  1461.20
# 1085            49            1     CHS         Stags   74  1440.72  1445.42
# 1088            49            1     BLB     Baltimore   75  1477.26  1484.31
# ...            ...          ...     ...           ...  ...      ...      ...
# 122207          39            0     ATL         Hawks  110  1505.05  1487.59
# 123916           8            0     HOU       Rockets  113  1635.77  1642.45
# 123917           7            0     MIN  Timberwolves  101  1502.92  1496.24
# 124862          40            0     MIL         Bucks   95  1499.90  1505.86
# 124863          41            0     NYK        Knicks   79  1304.46  1298.50
#
#         win_equiv opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 930         47.07    BLB     Baltimore       95    1434.05    1448.50
# 931         46.41    WSC      Capitols       71    1469.35    1454.90
# 1084        47.71    CHS         Stags       74    1440.72    1445.42
# 1085        46.09    WSC      Capitols       70    1465.90    1461.20
# 1088        50.04    CHS         Stags       72    1445.42    1438.36
# ...           ...    ...           ...      ...        ...        ...
# 122207      39.24    BRK          Nets      127    1454.65    1472.11
# 123916      54.89    MIN  Timberwolves      101    1502.92    1496.24
# 123917      40.13    HOU       Rockets      113    1635.77    1642.45
# 124862      41.14    NYK        Knicks       79    1304.46    1298.50
# 124863      21.19    MIL         Bucks       95    1499.90    1505.86
#
#        game_location game_result  forecast  \
# 930                A           L      0.41
# 931                H           W      0.59
# 1084               A           L      0.39
# 1085               H           W      0.61
# 1088               A           W      0.40
# ...              ...         ...       ...
# 122207             N           L      0.57
# 123916             N           W      0.68
# 123917             N           L      0.32
# 124862             N           W      0.75
# 124863             N           L      0.25
#
#                                             notes  pts_diff  pts_diff_abs
# 930          at Baltimore's Fifth Regiment Armory       -24            24
# 931          at Baltimore's Fifth Regiment Armory        24            24
# 1084                                   Tiebreaker        -4             4
# 1085                                   Tiebreaker         4             4
# 1088                                   Tiebreaker         3             3
# ...                                           ...       ...           ...
# 122207                         at London, England       -17            17
# 123916  at Mexico City Arena, Mexico City, Mexico        12            12
# 123917  at Mexico City Arena, Mexico City, Mexico       -12            12
# 124862                 at The O2, London, England        16            16
# 124863                 at The O2, London, England       -16            16
#
# [5424 rows x 25 columns]

# %%
# nba_no_miss_col =
# Out:
#   File "C:\Users\ACER\AppData\Local\Temp\ipykernel_5404\2663599610.py", line 1
#     nba_no_miss_col =
#                       ^
# SyntaxError: invalid syntax

# %%
nba_copy = nba.copy()

# %%
nba_copy["notes"].fillna(
    value="No Note",
    inplace=True
)

# %%
nba_copy["notes"].describe()
# Out:
# count      126314
# unique        232
# top       No Note
# freq       120890
# Name: notes, dtype: object

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26684      13343  197210260VIR   ABA        1     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  pts    elo_i    elo_n  \
# 26684           7            0     DNR  Nuggets    0  1460.34  1457.45
#
#        win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 26684      40.41    VIR  Squires        2    1484.19    1487.08             A
#
#       game_result  forecast                           notes  pts_diff  \
# 26684           L      0.33  at Richmond VA; forfeit to VIR        -2
#
#        pts_diff_abs
# 26684             2

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam      100             5.0
# Tokyo          700             9.0
# Toronto        323             NaN

# %%
another_city_data = pd.DataFrame(
    {
        "revenue" : [4500, 8000],
        "employee_count": [2,2]
    }
    .index["New York", "Barcelona"]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5404\1391717213.py in <module>
#       1 another_city_data = pd.DataFrame(
# ----> 2     {
#       3         "revenue" : [4500, 8000],
#       4         "employee_count": [2,2]
#       5     }
#
# AttributeError: 'dict' object has no attribute 'index'

# %% [markdown]
# ### Ada 3 function untuk join pandas
# appen
# merge
# concat

# %% [markdown]
# ### DOKUMENTASI ADALAH TEMAN KALIAN WKWKWK
